# %% [markdown]
# # This code reads out various data sets and compares data availabily across several data sets

# %%
import os
import pandas as pd
import numpy as np
from pandas_datareader import wb
# %load_ext autoreload
# %autoreload 2

# %%
cwd = os.getcwd()
os.chdir("../git/wb_api_wrapper/")
from  wb_api_wrapper import * #Import functions to obtain World Bank data from the web and code to rename country names
os.chdir(cwd) #Get back to initial working directory

# %% [markdown]
# Get a dictionaty translating country spellings to the spelling usually used by the World Bank data sets

# %%
any_name_to_wb_name = pd.read_csv("../git/country_names/out/any_name_to_wb_name.csv",index_col="any",squeeze=True, encoding="utf-8")

# %% [markdown]
# The goal of this Notebook is to create a matrix of countries and the availability of indicators relevant for assessing resilience. We start off with loading some work which has been done already, contained in the file have_and_have_nots.csv.

# %%
data_matrix = pd.read_csv('have_and_have_nots.csv', index_col=0, squeeze=True, encoding="utf-8")

# %%
data_matrix.head(3)
# Out:
#             Code                      Region         Income group  \
# Economy
# Afghanistan  AFG                  South Asia           Low income
# Albania      ALB       Europe & Central Asia  Upper middle income
# Algeria      DZA  Middle East & North Africa  Upper middle income
#
#             Lending category  HIPC  Data  \
# Economy
# Afghanistan              IDA  HIPC     0
# Albania                 IBRD   NaN     1
# Algeria                 IBRD   NaN     0
#
#                                                   missing_data
# Economy
# Afghanistan                                   plgp, avg_prod_k
# Albania                                                    NaN
# Algeria      share1, social_p, social_r, avg_prod_k, share1...

# %%
data_matrix.index #This provides and idea of how many countries are contained in data_matrix
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, RB', 'Vietnam',
#        'Virgin Islands (U.S.)', 'West Bank and Gaza', 'Yemen, Rep.', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Economy', length=214)

# %% [markdown]
# Check if all the names in data_matrix are spelled according to WB spelling, and correct if not.

# %%
diff_data = data_matrix.index.difference(any_name_to_wb_name) # This command shows differences in the dataset
diff_data
# Out:
# Index(['Cabo Verde', 'Channel Islands', 'Curaçao', 'Côte d'Ivoire', 'Kosovo',
#        'Sint Maarten (Dutch part)', 'São Tomé and Principe'],
#       dtype='object', name='Economy')

# %%
diff_index = data_matrix.index.difference(any_name_to_wb_name.index) # This command shows differences in the index
diff_index
# Out:
# Index(['Channel Islands', 'Curaçao', 'Kosovo', 'Sint Maarten (Dutch part)'], dtype='object')

# %% [markdown]
# Names which appear in both commands 'data_matrix.index.difference(any_name_to_wb_name)' and 'data_matrix.index.difference(any_name_to_wb_name.index)' are missing from the dataset. Names which appear ONLY in 'data_matrix.index.difference(any_name_to_wb_name)' require renaming.

# %%
diff_data.difference(diff_index) #These entries need to be renamed.
# Out:
# Index(['Cabo Verde', 'Côte d'Ivoire', 'São Tomé and Principe'], dtype='object')

# %%
diff_index.difference(diff_data) # These entries are not in the country_name database.
# Out:
# Index([], dtype='object')

# %% [markdown]
# Translate the names in data_matrix.index so that they meet the World Bank type spelling

# %%
data_matrix = data_matrix.rename(index=any_name_to_wb_name) # This is a sweet one-line command to rename the index using a dictionary-like translation, in this case an_name_to_wb_name

# %% [markdown]
# # Now obtain further indicators from locally saved csv files. See the Notebook pull_data_wb

# %%
wb_data_inc20 = pd.read_csv('wb_data_raw/SI.DST.FRST.20.csv', encoding='utf-8').head(10)

# %%
wb_data_inc20
# Out:
#       country  value  year
# 0     Albania   8.85  2012
# 1     Algeria   6.96  1995
# 2      Angola   5.43  2008
# 3   Argentina   4.75  2013
# 4     Armenia   8.48  2013
# 5   Australia   7.09  2010
# 6     Austria   7.78  2012
# 7  Azerbaijan  13.37  2005
# 8  Bangladesh   8.89  2010
# 9     Belarus   9.65  2012

# %% [markdown]
# Now use the function mrv from wb_api_wrapper to keep only the latest entry and the year of the latest entry. This is done in order to simplify the DataFrame and thus make it easier to handle. The MultiIndex will be changed to an Index containing only the country names (in this case).

# %%
wb_data_inc20 = mrv(wb_data_inc20,include_year=True) #Careful, entries with only NaNs are dropped when using function mrv!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-386e940eae34> in <module>()
# ----> 1 wb_data_inc20 = mrv(wb_data_inc20,include_year=True) #Careful, entries with only NaNs are dropped when using function mrv!
#
# /Users/steffen/Documents/Forschung/WB Resilience/Indicator/git/wb_api_wrapper/wb_api_wrapper.py in mrv(data, include_year)
#      61 def mrv(data,include_year=False):
#      62     """most recent values from a dataframe. assumes one column is called 'year'"""
# ---> 63     return lrv_or_mrv(data,"most",include_year)
#      64
#      65 def lrv(data,include_year=False):
#
# /Users/steffen/Documents/Forschung/WB Resilience/Indicator/git/wb_api_wrapper/wb_api_wrapper.py in lrv_or_mrv(data, least_or_most, include_year)
#      76
#      77     #removes nans, and takes the least or most recent value. hop has a horrible shape
# ---> 78     hop=data.reset_index().dropna().groupby("country").apply(mlrv_gp,least_or_most,include_year)
#      79
#      80     if include_year:
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3434         axis = self._get_axis_number(axis)
#    3435         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3436                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3437
#    3438     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1309         raise TypeError('invalid type: %s' % type(obj))
#    1310
# -> 1311     return klass(obj, by, **kwds)
#    1312
#    1313
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze)
#     416         if grouper is None:
#     417             grouper, exclusions, obj = _get_grouper(obj, keys, axis=axis,
# --> 418                                                     level=level, sort=sort)
#     419
#     420         self.obj = obj
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort)
#    2262
#    2263         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2264             in_axis, name, gpr = True, gpr, obj[gpr]
#    2265             exclusions.append(name)
#    2266
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/index.py in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'country'

# %% [markdown]
# Now we also should rename the column labels before concatenating this table with data_matrix

# %%
wb_data_inc20.rename(columns={'value':'income share bottom quint.', 'year':'income share bottom quint: year'}, inplace=True)
wb_data_inc20['income share bottom quint.'] = wb_data_inc20['income share bottom quint.'] / 100 #Transform percentage to fraction
wb_data_inc20.head(2)
# Out:
#          income share bottom quint. income share bottom quint: year
# country
# Albania                      0.0885                            2012
# Algeria                      0.0696                            1995

# %% [markdown]
# Concatenate, i.e. add, the new data to the existing data matrix

# %%
data_matrix = pd.concat([data_matrix, wb_data_inc20], axis=1)
data_matrix.head(8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a36fcc84c37b> in <module>()
# ----> 1 data_matrix = pd.concat([data_matrix, wb_data_inc20], axis=1)
#       2 data_matrix.head(8)
#
# NameError: name 'wb_data_inc20' is not defined

# %% [markdown]
# ## Now load finance access data from FINDEX (Global Financial Inclusion Database)

# %%
wb_findex = pd.read_csv('wb_data_raw/FINDEX_selection.csv', index_col=0, encoding='utf-8')

# %% [markdown]
# Change the index to country

# %%
wb_findex
# Out:
#                                              year  WP11648.1  WP11648.8  \
# country
# East Asia & Pacific (developing only)         MRV  28.516100  15.334840
# East Asia & Pacific (developing only)        2014        NaN        NaN
# East Asia & Pacific (developing only)        2011  28.516100  15.334840
# Euro area                                     MRV  40.837310  40.125610
# Euro area                                    2014        NaN        NaN
# Euro area                                    2011  40.837310  40.125610
# Europe & Central Asia (developing only)       MRV   4.909911   2.438396
# Europe & Central Asia (developing only)      2014        NaN        NaN
# Europe & Central Asia (developing only)      2011   4.909911   2.438396
# High income                                   MRV  40.890730  34.167710
# High income                                  2014        NaN        NaN
# High income                                  2011  40.890730  34.167710
# High income: nonOECD                          MRV  18.064500  13.174700
# High income: nonOECD                         2014        NaN        NaN
# High income: nonOECD                         2011  18.064500  13.174700
# High income: OECD                             MRV  45.270530  37.764660
# High income: OECD                            2014        NaN        NaN
# High income: OECD                            2011  45.270530  37.764660
# Latin America & Caribbean (developing only)   MRV   9.644223   4.833948
# Latin America & Caribbean (developing only)  2014        NaN        NaN
# Latin America & Caribbean (developing only)  2011   9.644223   4.833948
# Low & middle income                           MRV  17.627090  10.466980
# Low & middle income                          2014        NaN        NaN
# Low & middle income                          2011  17.627090  10.466980
# Low income                                    MRV  11.525440   7.760553
# Low income                                   2014        NaN        NaN
# Low income                                   2011  11.525440   7.760553
# Lower middle income                           MRV  11.094830   7.680662
# Lower middle income                          2014        NaN        NaN
# Lower middle income                          2011  11.094830   7.680662
# ...                                           ...        ...        ...
# United Kingdom                                MRV  43.799340  41.194090
# United Kingdom                               2014        NaN        NaN
# United Kingdom                               2011  43.799340  41.194090
# United States                                 MRV  50.397870  33.614190
# United States                                2014        NaN        NaN
# United States                                2011  50.397870  33.614190
# Uruguay                                       MRV   5.692473   1.661895
# Uruguay                                      2014        NaN        NaN
# Uruguay                                      2011   5.692473   1.661895
# Uzbekistan                                    MRV   0.821250   0.689215
# Uzbekistan                                   2014        NaN        NaN
# Uzbekistan                                   2011   0.821250   0.689215
# Venezuela, RB                                 MRV  13.569290   6.972021
# Venezuela, RB                                2014        NaN        NaN
# Venezuela, RB                                2011  13.569290   6.972021
# Vietnam                                       MRV   7.740848   3.995232
# Vietnam                                      2014        NaN        NaN
# Vietnam                                      2011   7.740848   3.995232
# West Bank and Gaza                            MRV   5.477625   0.530294
# West Bank and Gaza                           2014        NaN        NaN
# West Bank and Gaza                           2011   5.477625   0.530294
# Yemen, Rep.                                   MRV   1.073977   0.000000
# Yemen, Rep.                                  2014        NaN        NaN
# Yemen, Rep.                                  2011   1.073977   0.000000
# Zambia                                        MRV  11.765850   2.737125
# Zambia                                       2014        NaN        NaN
# Zambia                                       2011  11.765850   2.737125
# Zimbabwe                                      MRV  17.268240  10.452920
# Zimbabwe                                     2014        NaN        NaN
# Zimbabwe                                     2011  17.268240  10.452920
#
#                                              WP15165.1  WP15165.8  \
# country
# East Asia & Pacific (developing only)        36.493060  26.096030
# East Asia & Pacific (developing only)        36.493060  26.096030
# East Asia & Pacific (developing only)              NaN        NaN
# Euro area                                    47.645660  37.590640
# Euro area                                    47.645660  37.590640
# Euro area                                          NaN        NaN
# Europe & Central Asia (developing only)       8.368120   4.255587
# Europe & Central Asia (developing only)       8.368120   4.255587
# Europe & Central Asia (developing only)            NaN        NaN
# High income                                  46.740970  36.405710
# High income                                  46.740970  36.405710
# High income                                        NaN        NaN
# High income: nonOECD                         21.222550  16.461350
# High income: nonOECD                         21.222550  16.461350
# High income: nonOECD                               NaN        NaN
# High income: OECD                            51.585160  40.295790
# High income: OECD                            51.585160  40.295790
# High income: OECD                                  NaN        NaN
# Latin America & Caribbean (developing only)  13.455920   6.921207
# Latin America & Caribbean (developing only)  13.455920   6.921207
# Latin America & Caribbean (developing only)        NaN        NaN
# Low & middle income                          22.477070  14.811790
# Low & middle income                          22.477070  14.811790
# Low & middle income                                NaN        NaN
# Low income                                    9.941459   5.052696
# Low income                                    9.941459   5.052696
# Low income                                         NaN        NaN
# Lower middle income                          14.756110   7.945868
# Lower middle income                          14.756110   7.945868
# Lower middle income                                NaN        NaN
# ...                                                ...        ...
# United Kingdom                               52.298590  36.570890
# United Kingdom                               52.298590  36.570890
# United Kingdom                                     NaN        NaN
# United States                                54.113850  38.833190
# United States                                54.113850  38.833190
# United States                                      NaN        NaN
# Uruguay                                      12.460760   5.289780
# Uruguay                                      12.460760   5.289780
# Uruguay                                            NaN        NaN
# Uzbekistan                                    1.836558   0.814144
# Uzbekistan                                    1.836558   0.814144
# Uzbekistan                                         NaN        NaN
# Venezuela, RB                                22.789150  18.761620
# Venezuela, RB                                22.789150  18.761620
# Venezuela, RB                                      NaN        NaN
# Vietnam                                      14.605790   9.144979
# Vietnam                                      14.605790   9.144979
# Vietnam                                            NaN        NaN
# West Bank and Gaza                            5.097842   1.446696
# West Bank and Gaza                            5.097842   1.446696
# West Bank and Gaza                                 NaN        NaN
# Yemen, Rep.                                   0.860973   0.086413
# Yemen, Rep.                                   0.860973   0.086413
# Yemen, Rep.                                        NaN        NaN
# Zambia                                       16.844360   5.518931
# Zambia                                       16.844360   5.518931
# Zambia                                             NaN        NaN
# Zimbabwe                                      5.194062   0.832974
# Zimbabwe                                      5.194062   0.832974
# Zimbabwe                                           NaN        NaN
#
#                                              WP_time_04.8
# country
# East Asia & Pacific (developing only)           26.096030
# East Asia & Pacific (developing only)           26.096030
# East Asia & Pacific (developing only)           15.334840
# Euro area                                       37.590640
# Euro area                                       37.590640
# Euro area                                       40.125610
# Europe & Central Asia (developing only)          4.255587
# Europe & Central Asia (developing only)          4.255587
# Europe & Central Asia (developing only)          2.438396
# High income                                     36.405710
# High income                                     36.405710
# High income                                     34.167710
# High income: nonOECD                            16.461350
# High income: nonOECD                            16.461350
# High income: nonOECD                            13.174700
# High income: OECD                               40.295790
# High income: OECD                               40.295790
# High income: OECD                               37.764660
# Latin America & Caribbean (developing only)      6.921207
# Latin America & Caribbean (developing only)      6.921207
# Latin America & Caribbean (developing only)      4.833948
# Low & middle income                             14.811790
# Low & middle income                             14.811790
# Low & middle income                             10.466980
# Low income                                       5.052696
# Low income                                       5.052696
# Low income                                       7.760553
# Lower middle income                              7.945868
# Lower middle income                              7.945868
# Lower middle income                              7.680662
# ...                                                   ...
# United Kingdom                                  36.570890
# United Kingdom                                  36.570890
# United Kingdom                                  41.194090
# United States                                   38.833190
# United States                                   38.833190
# United States                                   33.614190
# Uruguay                                          5.289780
# Uruguay                                          5.289780
# Uruguay                                          1.661895
# Uzbekistan                                       0.814144
# Uzbekistan                                       0.814144
# Uzbekistan                                       0.689215
# Venezuela, RB                                   18.761620
# Venezuela, RB                                   18.761620
# Venezuela, RB                                    6.972021
# Vietnam                                          9.144979
# Vietnam                                          9.144979
# Vietnam                                          3.995232
# West Bank and Gaza                               1.446696
# West Bank and Gaza                               1.446696
# West Bank and Gaza                               0.530294
# Yemen, Rep.                                      0.086413
# Yemen, Rep.                                      0.086413
# Yemen, Rep.                                      0.000000
# Zambia                                           5.518931
# Zambia                                           5.518931
# Zambia                                           2.737125
# Zimbabwe                                         0.832974
# Zimbabwe                                         0.832974
# Zimbabwe                                        10.452920
#
# [516 rows x 6 columns]

# %%
# Out:
# <bound method NDFrame.describe of                                                                                  country  \
# country
# East Asia & Pacific (developing only)              East Asia & Pacific (developing only)
# East Asia & Pacific (developing only)              East Asia & Pacific (developing only)
# East Asia & Pacific (developing only)              East Asia & Pacific (developing only)
# Euro area                                                                      Euro area
# Euro area                                                                      Euro area
# Euro area                                                                      Euro area
# Europe & Central Asia (developing only)          Europe & Central Asia (developing only)
# Europe & Central Asia (developing only)          Europe & Central Asia (developing only)
# Europe & Central Asia (developing only)          Europe & Central Asia (developing only)
# High income                                                                  High income
# High income                                                                  High income
# High income                                                                  High income
# High income: nonOECD                                                High income: nonOECD
# High income: nonOECD                                                High income: nonOECD
# High income: nonOECD                                                High income: nonOECD
# High income: OECD                                                      High income: OECD
# High income: OECD                                                      High income: OECD
# High income: OECD                                                      High income: OECD
# Latin America & Caribbean (developing only)  Latin America & Caribbean (developing only)
# Latin America & Caribbean (developing only)  Latin America & Caribbean (developing only)
# Latin America & Caribbean (developing only)  Latin America & Caribbean (developing only)
# Low & middle income                                                  Low & middle income
# Low & middle income                                                  Low & middle income
# Low & middle income                                                  Low & middle income
# Low income                                                                    Low income
# Low income                                                                    Low income
# Low income                                                                    Low income
# Lower middle income                                                  Lower middle income
# Lower middle income                                                  Lower middle income
# Lower middle income                                                  Lower middle income
# ...                                                                                  ...
# United Kingdom                                                            United Kingdom
# United Kingdom                                                            United Kingdom
# United Kingdom                                                            United Kingdom
# United States                                                              United States
# United States                                                              United States
# United States                                                              United States
# Uruguay                                                                          Uruguay
# Uruguay                                                                          Uruguay
# Uruguay                                                                          Uruguay
# Uzbekistan                                                                    Uzbekistan
# Uzbekistan                                                                    Uzbekistan
# Uzbekistan                                                                    Uzbekistan
# Venezuela, RB                                                              Venezuela, RB
# Venezuela, RB                                                              Venezuela, RB
# Venezuela, RB                                                              Venezuela, RB
# Vietnam                                                                          Vietnam
# Vietnam                                                                          Vietnam
# Vietnam                                                                          Vietnam
# West Bank and Gaza                                                    West Bank and Gaza
# West Bank and Gaza                                                    West Bank and Gaza
# West Bank and Gaza                                                    West Bank and Gaza
# Yemen, Rep.                                                                  Yemen, Rep.
# Yemen, Rep.                                                                  Yemen, Rep.
# Yemen, Rep.                                                                  Yemen, Rep.
# Zambia                                                                            Zambia
# Zambia                                                                            Zambia
# Zambia                                                                            Zambia
# Zimbabwe                                                                        Zimbabwe
# Zimbabwe                                                                        Zimbabwe
# Zimbabwe                                                                        Zimbabwe
#
#                                              year  WP11648.1  WP11648.8  \
# country
# East Asia & Pacific (developing only)         MRV  28.516100  15.334840
# East Asia & Pacific (developing only)        2014        NaN        NaN
# East Asia & Pacific (developing only)        2011  28.516100  15.334840
# Euro area                                     MRV  40.837310  40.125610
# Euro area                                    2014        NaN        NaN
# Euro area                                    2011  40.837310  40.125610
# Europe & Central Asia (developing only)       MRV   4.909911   2.438396
# Europe & Central Asia (developing only)      2014        NaN        NaN
# Europe & Central Asia (developing only)      2011   4.909911   2.438396
# High income                                   MRV  40.890730  34.167710
# High income                                  2014        NaN        NaN
# High income                                  2011  40.890730  34.167710
# High income: nonOECD                          MRV  18.064500  13.174700
# High income: nonOECD                         2014        NaN        NaN
# High income: nonOECD                         2011  18.064500  13.174700
# High income: OECD                             MRV  45.270530  37.764660
# High income: OECD                            2014        NaN        NaN
# High income: OECD                            2011  45.270530  37.764660
# Latin America & Caribbean (developing only)   MRV   9.644223   4.833948
# Latin America & Caribbean (developing only)  2014        NaN        NaN
# Latin America & Caribbean (developing only)  2011   9.644223   4.833948
# Low & middle income                           MRV  17.627090  10.466980
# Low & middle income                          2014        NaN        NaN
# Low & middle income                          2011  17.627090  10.466980
# Low income                                    MRV  11.525440   7.760553
# Low income                                   2014        NaN        NaN
# Low income                                   2011  11.525440   7.760553
# Lower middle income                           MRV  11.094830   7.680662
# Lower middle income                          2014        NaN        NaN
# Lower middle income                          2011  11.094830   7.680662
# ...                                           ...        ...        ...
# United Kingdom                                MRV  43.799340  41.194090
# United Kingdom                               2014        NaN        NaN
# United Kingdom                               2011  43.799340  41.194090
# United States                                 MRV  50.397870  33.614190
# United States                                2014        NaN        NaN
# United States                                2011  50.397870  33.614190
# Uruguay                                       MRV   5.692473   1.661895
# Uruguay                                      2014        NaN        NaN
# Uruguay                                      2011   5.692473   1.661895
# Uzbekistan                                    MRV   0.821250   0.689215
# Uzbekistan                                   2014        NaN        NaN
# Uzbekistan                                   2011   0.821250   0.689215
# Venezuela, RB                                 MRV  13.569290   6.972021
# Venezuela, RB                                2014        NaN        NaN
# Venezuela, RB                                2011  13.569290   6.972021
# Vietnam                                       MRV   7.740848   3.995232
# Vietnam                                      2014        NaN        NaN
# Vietnam                                      2011   7.740848   3.995232
# West Bank and Gaza                            MRV   5.477625   0.530294
# West Bank and Gaza                           2014        NaN        NaN
# West Bank and Gaza                           2011   5.477625   0.530294
# Yemen, Rep.                                   MRV   1.073977   0.000000
# Yemen, Rep.                                  2014        NaN        NaN
# Yemen, Rep.                                  2011   1.073977   0.000000
# Zambia                                        MRV  11.765850   2.737125
# Zambia                                       2014        NaN        NaN
# Zambia                                       2011  11.765850   2.737125
# Zimbabwe                                      MRV  17.268240  10.452920
# Zimbabwe                                     2014        NaN        NaN
# Zimbabwe                                     2011  17.268240  10.452920
#
#                                              WP15165.1  WP15165.8  \
# country
# East Asia & Pacific (developing only)        36.493060  26.096030
# East Asia & Pacific (developing only)        36.493060  26.096030
# East Asia & Pacific (developing only)              NaN        NaN
# Euro area                                    47.645660  37.590640
# Euro area                                    47.645660  37.590640
# Euro area                                          NaN        NaN
# Europe & Central Asia (developing only)       8.368120   4.255587
# Europe & Central Asia (developing only)       8.368120   4.255587
# Europe & Central Asia (developing only)            NaN        NaN
# High income                                  46.740970  36.405710
# High income                                  46.740970  36.405710
# High income                                        NaN        NaN
# High income: nonOECD                         21.222550  16.461350
# High income: nonOECD                         21.222550  16.461350
# High income: nonOECD                               NaN        NaN
# High income: OECD                            51.585160  40.295790
# High income: OECD                            51.585160  40.295790
# High income: OECD                                  NaN        NaN
# Latin America & Caribbean (developing only)  13.455920   6.921207
# Latin America & Caribbean (developing only)  13.455920   6.921207
# Latin America & Caribbean (developing only)        NaN        NaN
# Low & middle income                          22.477070  14.811790
# Low & middle income                          22.477070  14.811790
# Low & middle income                                NaN        NaN
# Low income                                    9.941459   5.052696
# Low income                                    9.941459   5.052696
# Low income                                         NaN        NaN
# Lower middle income                          14.756110   7.945868
# Lower middle income                          14.756110   7.945868
# Lower middle income                                NaN        NaN
# ...                                                ...        ...
# United Kingdom                               52.298590  36.570890
# United Kingdom                               52.298590  36.570890
# United Kingdom                                     NaN        NaN
# United States                                54.113850  38.833190
# United States                                54.113850  38.833190
# United States                                      NaN        NaN
# Uruguay                                      12.460760   5.289780
# Uruguay                                      12.460760   5.289780
# Uruguay                                            NaN        NaN
# Uzbekistan                                    1.836558   0.814144
# Uzbekistan                                    1.836558   0.814144
# Uzbekistan                                         NaN        NaN
# Venezuela, RB                                22.789150  18.761620
# Venezuela, RB                                22.789150  18.761620
# Venezuela, RB                                      NaN        NaN
# Vietnam                                      14.605790   9.144979
# Vietnam                                      14.605790   9.144979
# Vietnam                                            NaN        NaN
# West Bank and Gaza                            5.097842   1.446696
# West Bank and Gaza                            5.097842   1.446696
# West Bank and Gaza                                 NaN        NaN
# Yemen, Rep.                                   0.860973   0.086413
# Yemen, Rep.                                   0.860973   0.086413
# Yemen, Rep.                                        NaN        NaN
# Zambia                                       16.844360   5.518931
# Zambia                                       16.844360   5.518931
# Zambia                                             NaN        NaN
# Zimbabwe                                      5.194062   0.832974
# Zimbabwe                                      5.194062   0.832974
# Zimbabwe                                           NaN        NaN
#
#                                              WP_time_04.8
# country
# East Asia & Pacific (developing only)           26.096030
# East Asia & Pacific (developing only)           26.096030
# East Asia & Pacific (developing only)           15.334840
# Euro area                                       37.590640
# Euro area                                       37.590640
# Euro area                                       40.125610
# Europe & Central Asia (developing only)          4.255587
# Europe & Central Asia (developing only)          4.255587
# Europe & Central Asia (developing only)          2.438396
# High income                                     36.405710
# High income                                     36.405710
# High income                                     34.167710
# High income: nonOECD                            16.461350
# High income: nonOECD                            16.461350
# High income: nonOECD                            13.174700
# High income: OECD                               40.295790
# High income: OECD                               40.295790
# High income: OECD                               37.764660
# Latin America & Caribbean (developing only)      6.921207
# Latin America & Caribbean (developing only)      6.921207
# Latin America & Caribbean (developing only)      4.833948
# Low & middle income                             14.811790
# Low & middle income                             14.811790
# Low & middle income                             10.466980
# Low income                                       5.052696
# Low income                                       5.052696
# Low income                                       7.760553
# Lower middle income                              7.945868
# Lower middle income                              7.945868
# Lower middle income                              7.680662
# ...                                                   ...
# United Kingdom                                  36.570890
# United Kingdom                                  36.570890
# United Kingdom                                  41.194090
# United States                                   38.833190
# United States                                   38.833190
# United States                                   33.614190
# Uruguay                                          5.289780
# Uruguay                                          5.289780
# Uruguay                                          1.661895
# Uzbekistan                                       0.814144
# Uzbekistan                                       0.814144
# Uzbekistan                                       0.689215
# Venezuela, RB                                   18.761620
# Venezuela, RB                                   18.761620
# Venezuela, RB                                    6.972021
# Vietnam                                          9.144979
# Vietnam                                          9.144979
# Vietnam                                          3.995232
# West Bank and Gaza                               1.446696
# West Bank and Gaza                               1.446696
# West Bank and Gaza                               0.530294
# Yemen, Rep.                                      0.086413
# Yemen, Rep.                                      0.086413
# Yemen, Rep.                                      0.000000
# Zambia                                           5.518931
# Zambia                                           5.518931
# Zambia                                           2.737125
# Zimbabwe                                         0.832974
# Zimbabwe                                         0.832974
# Zimbabwe                                        10.452920
#
# [516 rows x 7 columns]>

# %%
mrv(wb_findex)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-22c6bead6f12> in <module>()
# ----> 1 mrv(wb_findex)
#
# /Users/steffen/Documents/Forschung/WB Resilience/Indicator/git/wb_api_wrapper/wb_api_wrapper.py in mrv(data, include_year)
#      61 def mrv(data,include_year=False):
#      62     """most recent values from a dataframe. assumes one column is called 'year'"""
# ---> 63     return lrv_or_mrv(data,"most",include_year)
#      64
#      65 def lrv(data,include_year=False):
#
# /Users/steffen/Documents/Forschung/WB Resilience/Indicator/git/wb_api_wrapper/wb_api_wrapper.py in lrv_or_mrv(data, least_or_most, include_year)
#      76
#      77     #removes nans, and takes the least or most recent value. hop has a horrible shape
# ---> 78     hop=data.reset_index().dropna().groupby("country").apply(mlrv_gp,least_or_most,include_year)
#      79
#      80     if include_year:
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     713         # ignore SettingWithCopy here in case the user mutates
#     714         with option_context('mode.chained_assignment',None):
# --> 715             return self._python_apply_general(f)
#     716
#     717     def _python_apply_general(self, f):
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     717     def _python_apply_general(self, f):
#     718         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 719                                                    self.axis)
#     720
#     721         return self._wrap_applied_output(keys, values,
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1404             # group might be modified
#    1405             group_axes = _get_axes(group)
# -> 1406             res = f(group)
#    1407             if not _is_indexed_like(res, group_axes):
#    1408                 mutated = True
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in f(g)
#     709         @wraps(func)
#     710         def f(g):
# --> 711             return func(g, *args, **kwargs)
#     712
#     713         # ignore SettingWithCopy here in case the user mutates
#
# /Users/steffen/Documents/Forschung/WB Resilience/Indicator/git/wb_api_wrapper/wb_api_wrapper.py in mlrv_gp(x, least_or_most, include_year)
#      48         the_years =x["year"].min()
#      49     elif least_or_most=="most":
# ---> 50         the_years =x["year"].max()
#      51     else:
#      52         raise ValueError('least_or_most was not in ["least","most"]')
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/steffen/anaconda/lib/python3.5/site-packages/pandas/core/index.py in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'year'

# %% [markdown]
# ### Export the list of data availability to Excel and csv

# %%
data_matrix.to_excel("output/data_availability.xlsx")
data_matrix.to_csv("output/data_availability.csv")

# %% [markdown]
# # Now select only IDA countries from data_matrix

# %% [markdown]
# Choose the IDA countries, which means dropping the non-IDA countries.
# The cell below chooses all IDA countries, Blend countries and India and puts it into a new df called ida_countries

# %%
ida_countries = data_matrix.loc[data_matrix['Lending category'] == "Blend"]
ida_countries = ida_countries.append(data_matrix.loc[data_matrix['Lending category'] == "IDA"])
ida_countries = ida_countries.append(data_matrix.loc['India'])
ida_countries = ida_countries.sort_index()

# %% [markdown]
# Drop some of the columns which are not necessary for the IDA comparison

# %%
ida_countries.head(1)

# %%
ida_countries.drop(['Income group', 'missing_data', 'Data'], axis=1, inplace=True)

# %%
ida_countries.head(1)

# %% [markdown]
# Save the ida_countries file

# %% [markdown]
# Export the list of data availability to Excel and csv

# %%
ida_countries.to_excel("output/IDA_countries_data_availability.xlsx")
ida_countries.to_csv("output/IDA_countries_data_availability.csv")
